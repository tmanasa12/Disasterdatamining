# %%
# !git clone --depth=1 https://github.com/twintproject/twint.git
# %cd twint
# !git pull origin master
# !pip install -r requirements.txt
# !python setup.py install
# Out:
# Cloning into 'twint'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 47 (delta 3), reused 14 (delta 0), pack-reused 0
# Unpacking objects: 100% (47/47), done.
# /content/twint
# From https://github.com/twintproject/twint
#  * branch            master     -> FETCH_HEAD
# Already up to date.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 263 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 385 kB 53.9 MB/s
# ...
#      |████████████████████████████████| 288 kB 46.8 MB/s
# ...
#      |████████████████████████████████| 59 kB 7.0 MB/s
# ...
#      |████████████████████████████████| 140 kB 56.3 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.1 MB/s
# ...

# %%
# !pip install aiohttp==3.7.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.3 MB 4.3 MB/s
# ...
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.2
#     Uninstalling async-timeout-4.0.2:
#       Successfully uninstalled async-timeout-4.0.2
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.3
#     Uninstalling aiohttp-3.8.3:
#       Successfully uninstalled aiohttp-3.8.3
# ...

# %%
pip install nest-asyncio==1.5.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import twint
import nest_asyncio
nest_asyncio.apply()

# %%
c = twint.Config()
c.Search = "hurricane"
c.Store_json = True
c.Output = "/content/twint/Hurricanedata/tweets.json"
twint.run.Search(c)
# Out:
# 1589367351748988931 2022-11-06 21:21:20 +0000 <dan_vab> @czabe @TheGameMKE Can we do a double funeral and save money. Have the Miami Hurricane football program buried at the same time.
# 1589366783810895872 2022-11-06 21:19:04 +0000 <CJVAPES> @davidfrum @NHC_Atlantic @fema "accurate news"?  Not accurate from you, princess
# 1589366625450749952 2022-11-06 21:18:27 +0000 <THEMHL> Three games involving the @weekscrushers postponed as a result of Hurricane Fiona have been rescheduled:  Sept 23 - Pictou County at @MarinersHockey to Feb 20 Sept 29 - Yarmouth at Pictou County to Nov 20 Oct 6 - @ljackshockey at Pictou County to Dec 8   https://t.co/tl16gltsjN
# 1589365459249672194 2022-11-06 21:13:49 +0000 <Dreddpool82> @lisa_liberal @TomCottonAR You forgot to add to the democrats side, send 10's of $$ billions to the Ukraine, while not spending anything on US  citizens affected by the hurricane.
# ...

# %%
import pandas as pd

# %%
data = pd.read_json("/content/twint/Hurricanedata/tweets.json", lines= True)

# %%
data.shape
# Out:
# (130174, 36)

# %%
data.head(15)
# Out:
#                      id      conversation_id                created_at  \
# 0   1590796436685217792  1590796436685217792 2022-11-10 20:00:00+00:00
# 1   1590796436685217792  1590796436685217792 2022-11-10 20:00:00+00:00
# 2   1588258851232546817  1588256415440728064 2022-11-03 19:56:33+00:00
# 3   1588255385118736384  1588255385118736384 2022-11-03 19:42:46+00:00
# 4   1587846074047373313  1587846074047373312 2022-11-02 16:36:19+00:00
# 5   1587428284467482624  1587428284467482624 2022-11-01 12:56:10+00:00
# 6   1587181267891748870  1587124326507110400 2022-10-31 20:34:37+00:00
# 7   1587160699607945217  1587160699607945216 2022-10-31 19:12:53+00:00
# 8   1587135713757233152  1587135713757233152 2022-10-31 17:33:36+00:00
# 9   1587122239823937536  1587122239823937536 2022-10-31 16:40:03+00:00
# 10  1586922933158612994  1586922933158612992 2022-10-31 03:28:05+00:00
# 11  1586922154850934784  1586922154850934784 2022-10-31 03:24:59+00:00
# ...

# %%
pip install textacy.vsm

# %%
import re

import numpy as np
import pandas as pd
from nltk.tokenize import TweetTokenizer
from nltk import pos_tag, ne_chunk
from nltk.chunk import conlltags2tree, tree2conlltags
from nltk.tag.stanford import StanfordNERTagger
import nltk

from sklearn.feature_extraction.text import TfidfVectorizer
#from textacy.vsm import Vectorizer

from tqdm import *
from pprint import pprint

#from pymprog import *

# %%
data.dropna(inplace=True)
#data = data[data.retweets != 0]
data.to_csv('./preprocessed_tweets.csv')
data.shape
# Out:
# (130174, 36)

# %%
data.describe()
# Out:
#                  id  conversation_id  timezone       user_id  replies_count  \
# count  1.301740e+05     1.301740e+05  130174.0  1.301740e+05  130174.000000
# mean   1.590650e+18     1.589895e+18       0.0  6.305908e+17       0.796918
# std    7.542539e+14     1.768245e+16       0.0  6.628359e+17      17.922380
# min    1.584936e+18     1.538407e+10       0.0  2.910000e+02       0.000000
# 25%    1.590103e+18     1.590067e+18       0.0  2.597986e+08       0.000000
# 50%    1.590542e+18     1.590510e+18       0.0  4.700886e+09       0.000000
# 75%    1.591051e+18     1.590939e+18       0.0  1.336853e+18       1.000000
# max    1.592616e+18     1.592616e+18       0.0  1.592611e+18    3783.000000
#
#        retweets_count    likes_count          video
# count   130174.000000  130174.000000  130174.000000
# mean         1.713798      10.525527       0.206654
# std         58.873515     343.536606       0.404907
# min          0.000000       0.000000       0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130174 entries, 0 to 130173
# Data columns (total 36 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               130174 non-null  int64
#  1   conversation_id  130174 non-null  int64
#  2   created_at       130174 non-null  datetime64[ns, UTC]
#  3   date             130174 non-null  datetime64[ns]
#  4   time             130174 non-null  object
#  5   timezone         130174 non-null  int64
#  6   user_id          130174 non-null  int64
#  7   username         130174 non-null  object
#  8   name             130174 non-null  object
#  9   place            130174 non-null  object
#  10  tweet            130174 non-null  object
#  11  language         130174 non-null  object
#  12  mentions         130174 non-null  object
#  13  urls             130174 non-null  object
#  14  photos           130174 non-null  object
#  15  replies_count    130174 non-null  int64
# ...
